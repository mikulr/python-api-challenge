# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
long= []
temp = []
maxtemp=[]
humid=[]
cloud=[]
windsp=[]
country=[]
date=[]
name=[]
city_ct=0

print('Beginning Data Retrieval')     
print ("-----------------------------")
# Loop through the list of cities and perform a request for data on each
#set try/except to pass over the cities that are not found in the API (they will show as a KeyError)
#utilize a simple counter to add a 30 second sleep every 50 calls to keep in compliance with API
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        windsp.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        name.append(response['name'])
        city_ct = city_ct + 1
        if (city_ct % 50 == 0):
            time.sleep(30)
    except KeyError:
        print("City not found. Skipping.....")
     
        
#print result of calls to screen:
    print (f"Processing Record {city_ct} for {city}")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping.....
# Processing Record 0 for sentyabrskiy
# Processing Record 1 for dikson
# Processing Record 2 for punta arenas
# Processing Record 3 for leshukonskoye
# Processing Record 4 for vaini
# Processing Record 5 for busselton
# Processing Record 6 for newry
# Processing Record 7 for belyy yar
# Processing Record 8 for nikolskoye
# Processing Record 9 for batouri
# Processing Record 10 for enid
# Processing Record 11 for avarua
# Processing Record 12 for namibe
# Processing Record 13 for cherskiy
# Processing Record 14 for chuy
# Processing Record 15 for bluff
# Processing Record 16 for khatanga
# Processing Record 17 for arraial do cabo
# City not found. Skipping.....
# Processing Record 17 for illoqqortoormiut
# Processing Record 18 for sitka
# Processing Record 19 for morant bay
# Processing Record 20 for codrington
# Processing Record 21 for port elizabeth
# Processing Record 22 for albany
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict={
    "City": name,
    "Latitude": lat,
    "Longitude": long,
    "Max Temperature": maxtemp,
    "Humidity": humid,
    "Cloudiness": cloud,
    "Wind Speed": windsp,
    "Country": country,
    "Date": date,
}
city_data_pd= pd.DataFrame(city_dict)
city_data_pd
# Out:
#               City  Latitude  Longitude  Max Temperature  Humidity  \
# 0           Dikson   73.5069    80.5464           -23.42       100
# 1     Punta Arenas  -53.1500   -70.9167            57.31        77
# 2    Leshukonskoye   64.8989    45.7622            13.80        93
# 3            Vaini  -21.2000  -175.2000            73.56        94
# 4        Busselton  -33.6500   115.3333            57.09        74
# ..             ...       ...        ...              ...       ...
# 554         Inongo   -1.9500    18.2667            82.99        55
# 555         Beyneu   45.3167    55.2000            29.84        72
# 556           Auki   -8.7676   160.7034            78.85        88
# 557      Kafr Sawm   32.6833    35.8000            55.29        78
# 558          Bilma   18.6853    12.9164            77.83         9
#
#      Cloudiness  Wind Speed Country        Date
# 0            73        7.31      RU  1644158118
# 1            75        6.91      CL  1644157935
# ...

# %%
#export to csv
city_data_pd.to_csv("output_data/cities.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#because I chose to not seed my cities, this need to be run each time because the data is fluid and changing 
#reduce the dataset by only taking the cities that have a humidity less than 100%
#rather than dropping the ones that dont meet the desired conditions, keep the ones that do   

clean_city_data=city_data_pd[city_data_pd["Humidity"] < 100]
clean_city_data.count()
# Out:
# City               541
# Latitude           541
# Longitude          541
# Max Temperature    541
# Humidity           541
# Cloudiness         541
# Wind Speed         541
# Country            541
# Date               541
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today=pd.Timestamp("today").strftime("%m/%d/%Y")
today
# Out:
# '02/06/2022'

# %%
x_values = clean_city_data['Latitude']
y_values = clean_city_data['Max Temperature']
plot_title='Global -City Latitude vs. Max Temperature'

plt.scatter(x_values,y_values)

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f'{plot_title} ({today})')

plt.savefig(f'output_data/plots/{plot_title}.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data['Latitude']
h_values = clean_city_data['Humidity']
plot_title='Global - City Latitude vs. Humidity'


plt.scatter(x_values,h_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'{plot_title} ({today})')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data['Latitude']
c_values = clean_city_data['Cloudiness']
plot_title='Global - City Latitude vs. Cloudiness'


plt.scatter(x_values,c_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'{plot_title} ({today})')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data['Latitude']
w_values = clean_city_data['Wind Speed']
plot_title='Global - City Latitude vs. Wind Speed'


plt.scatter(x_values,w_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'{plot_title} ({today})')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
x_values = clean_city_data['Latitude']
y_values = clean_city_data['Max Temperature']
plot_title='Global - City Latitude vs. Max Temperature'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title} regression.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.5700838206360407

# %%
#Filter together northern and southern hemispheres into their own DF's
northern_df=clean_city_data.loc[clean_city_data["Latitude"] >=0,:]
southern_df=clean_city_data.loc[clean_city_data["Latitude"] <0,:]

# %%
northern_df.head()
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 2  Leshukonskoye   64.8989    45.7622            13.80        93         100
# 5          Newry   54.1784    -6.3374            45.10        79          82
# 6      Belyy Yar   53.6039    91.3903            -2.31        84          99
# 7     Nikolskoye   59.7035    30.7861            34.72        89         100
# 8        Batouri    4.4333    14.3667            95.29        12          50
#
#    Wind Speed Country        Date
# 2        9.22      RU  1644158119
# 5       22.62      GB  1644158120
# 6        0.00      RU  1644158120
# 7       12.48      RU  1644158121
# 8        5.66      CM  1644158121

# %%
southern_df.head()
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 1   Punta Arenas  -53.1500   -70.9167            57.31        77          75
# 3          Vaini  -21.2000  -175.2000            73.56        94         100
# 4      Busselton  -33.6500   115.3333            57.09        74          65
# 11    Mossamedes  -15.1961    12.1522            78.55        59          92
# 13          Chui  -33.6971   -53.4616            67.98        71          82
#
#     Wind Speed Country        Date
# 1         6.91      CL  1644157935
# 3        20.71      TO  1644158119
# 4        14.56      AU  1644158120
# 11       15.97      AO  1644158122
# 13       12.12      UY  1644158122

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Max Temperature']
plot_title = 'Northern Hemisphere - City Latitude vs. Max Temp'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.7140394632601244

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Max Temperature']
plot_title='Southern Hemisphere - City Latitude vs. Max Temp'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.31999493426319053

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
h_values = northern_df['Humidity']
plot_title='Northern Hemisphere - City Latitude vs. Humidity'

# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, h_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,h_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.21213501049569436

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
h_values = southern_df['Humidity']
plot_title='Southern Hemisphere - City Latitude vs. Humidity'


# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, h_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,h_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.028266704205757484

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
c_values = northern_df['Cloudiness']
plot_title='Northern Hemisphere - City Latitude vs. Cloudiness'

# Perform a linear regression on cloudiness vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, c_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,c_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.06501499706600233

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
c_values = southern_df['Cloudiness']
plot_title='Southern Hemisphere - City Latitude vs. Cloudiness'

# Perform a linear regression on latitude vs cloudiness
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, c_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,c_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.2152412367118572

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
w_values = northern_df['Wind Speed']
plot_title='Northern Hemisphere - City Latitude vs. Wind Speed'


# Perform a linear regression on latitude vs wind speed
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, w_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,w_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.02289712307841694

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
w_values = southern_df['Wind Speed']
plot_title='Southern Hemisphere - City Latitude vs. Wind Speed'

# Perform a linear regression on latitude vs. windspeed
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, w_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,w_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} ({today})')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.05265511879798948

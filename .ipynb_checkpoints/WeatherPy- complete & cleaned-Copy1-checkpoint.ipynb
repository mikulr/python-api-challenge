# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
long= []
temp = []
maxtemp=[]
humid=[]
cloud=[]
windsp=[]
country=[]
date=[]
name=[]
city_ct=0

print('Beginning Data Retrieval')     
print ("-----------------------------")
# Loop through the list of cities and perform a request for data on each
#set try/except to pass over the cities that are not found in the API (they will show as a KeyError)
#utilize a simple counter to add a 30 second sleep every 50 calls to keep in compliance with API
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        windsp.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        name.append(response['name'])
        city_ct = city_ct + 1
        if (city_ct % 50 == 0):
            time.sleep(30)
    except KeyError:
        print("City not found. Skipping.....")
     
        
#print result of calls to screen:
    print (f"Processing Record {city_ct} for {city}")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping.....
# Processing Record 0 for amderma
# Processing Record 1 for arrecife
# Processing Record 2 for dikson
# City not found. Skipping.....
# Processing Record 2 for taolanaro
# Processing Record 3 for luderitz
# Processing Record 4 for rawson
# Processing Record 5 for barrow
# Processing Record 6 for talara
# Processing Record 7 for bredasdorp
# Processing Record 8 for dwarka
# Processing Record 9 for new norfolk
# Processing Record 10 for tanout
# Processing Record 11 for wakema
# Processing Record 12 for mataura
# Processing Record 13 for busselton
# Processing Record 14 for hobart
# Processing Record 15 for tasiilaq
# Processing Record 16 for punta arenas
# Processing Record 17 for qaanaaq
# Processing Record 18 for jamestown
# Processing Record 19 for port alfred
# Processing Record 20 for omboue
# Processing Record 21 for isangel
# Processing Record 22 for cidreira
# Processing Record 23 for chokurdakh
# Processing Record 24 for georgetown
# Processing Record 25 for minab
# Processing Record 26 for rikitea
# Processing Record 27 for vardo
# Processing Record 28 for maldonado
# Processing Record 29 for ribeira grande
# Processing Record 30 for ambulu
# Processing Record 31 for yar-sale
# Processing Record 32 for vung tau
# City not found. Skipping.....
# Processing Record 32 for bolungarvik
# Processing Record 33 for mahebourg
# Processing Record 34 for ostrovnoy
# Processing Record 35 for payo
# City not found. Skipping.....
# Processing Record 35 for buqayq
# Processing Record 36 for carutapera
# Processing Record 37 for avarua
# Processing Record 38 for rocha
# Processing Record 39 for nikolskoye
# Processing Record 40 for igarka
# Processing Record 41 for carnarvon
# Processing Record 42 for annavasal
# Processing Record 43 for kapaa
# Processing Record 44 for saint-philippe
# City not found. Skipping.....
# Processing Record 44 for tsihombe
# Processing Record 45 for ahipara
# Processing Record 46 for airai
# Processing Record 47 for olafsvik
# Processing Record 48 for ushuaia
# Processing Record 49 for bambous virieux
# Processing Record 50 for angoche
# Processing Record 51 for pedasi
# Processing Record 52 for haines junction
# Processing Record 53 for ola
# Processing Record 54 for talnakh
# Processing Record 55 for mareeba
# Processing Record 56 for linxia
# Processing Record 57 for sisimiut
# City not found. Skipping.....
# Processing Record 57 for grand river south east
# Processing Record 58 for hermanus
# City not found. Skipping.....
# Processing Record 58 for samusu
# Processing Record 59 for kodiak
# Processing Record 60 for serebryanyy bor
# Processing Record 61 for alta gracia
# Processing Record 62 for paamiut
# Processing Record 63 for mar del plata
# Processing Record 64 for plataresti
# Processing Record 65 for half moon bay
# Processing Record 66 for necochea
# Processing Record 67 for guerrero negro
# Processing Record 68 for harper
# Processing Record 69 for mao
# Processing Record 70 for kruisfontein
# Processing Record 71 for san quintin
# City not found. Skipping.....
# Processing Record 71 for tabiauea
# Processing Record 72 for xining
# Processing Record 73 for turukhansk
# Processing Record 74 for bandraboua
# Processing Record 75 for saskylakh
# Processing Record 76 for butaritari
# Processing Record 77 for panjab
# Processing Record 78 for amur
# Processing Record 79 for bella vista
# Processing Record 80 for timmins
# Processing Record 81 for maholi
# Processing Record 82 for norman wells
# Processing Record 83 for kismayo
# Processing Record 84 for arraial do cabo
# Processing Record 85 for severo-kurilsk
# Processing Record 86 for bluff
# Processing Record 87 for sur
# City not found. Skipping.....
# Processing Record 87 for attawapiskat
# City not found. Skipping.....
# Processing Record 87 for mys shmidta
# Processing Record 88 for castro
# Processing Record 89 for namibe
# Processing Record 90 for poum
# Processing Record 91 for tuktoyaktuk
# Processing Record 92 for kant
# Processing Record 93 for vao
# Processing Record 94 for satipo
# Processing Record 95 for paveh
# Processing Record 96 for hilo
# Processing Record 97 for leicester
# Processing Record 98 for puerto ayora
# Processing Record 99 for albany
# Processing Record 100 for sao filipe
# Processing Record 101 for tambura
# Processing Record 102 for souillac
# Processing Record 103 for lorengau
# City not found. Skipping.....
# Processing Record 103 for barentsburg
# Processing Record 104 for galdar
# Processing Record 105 for cape town
# Processing Record 106 for kahului
# Processing Record 107 for pacayas
# Processing Record 108 for kyzyl-suu
# Processing Record 109 for tual
# Processing Record 110 for santiago
# Processing Record 111 for kutum
# Processing Record 112 for hasaki
# Processing Record 113 for waitati
# City not found. Skipping.....
# Processing Record 113 for khormuj
# Processing Record 114 for dingle
# Processing Record 115 for thompson
# Processing Record 116 for kirovskiy
# Processing Record 117 for surab
# Processing Record 118 for orangeburg
# Processing Record 119 for guozhen
# Processing Record 120 for naze
# Processing Record 121 for qianguo
# Processing Record 122 for ponta do sol
# Processing Record 123 for provideniya
# Processing Record 124 for valdivia
# Processing Record 125 for sakaiminato
# Processing Record 126 for nanortalik
# Processing Record 127 for sestri levante
# Processing Record 128 for srandakan
# Processing Record 129 for san andres
# Processing Record 130 for taywarah
# Processing Record 131 for kavieng
# Processing Record 132 for sept-iles
# City not found. Skipping.....
# Processing Record 132 for umzimvubu
# Processing Record 133 for cairns
# Processing Record 134 for hithadhoo
# Processing Record 135 for atuona
# City not found. Skipping.....
# Processing Record 135 for tungkang
# City not found. Skipping.....
# Processing Record 135 for hunza
# Processing Record 136 for nizhniy tsasuchey
# Processing Record 137 for alofi
# Processing Record 138 for pouebo
# Processing Record 139 for kiama
# Processing Record 140 for plettenberg bay
# Processing Record 141 for belle fourche
# Processing Record 142 for yellowknife
# Processing Record 143 for aklavik
# Processing Record 144 for krasnoselkup
# Processing Record 145 for challans
# Processing Record 146 for cloquet
# Processing Record 147 for segezha
# Processing Record 148 for vestmannaeyjar
# Processing Record 149 for gilgit
# City not found. Skipping.....
# Processing Record 149 for belushya guba
# Processing Record 150 for surman
# Processing Record 151 for hobyo
# City not found. Skipping.....
# Processing Record 151 for marcona
# Processing Record 152 for kedougou
# Processing Record 153 for kaduqli
# Processing Record 154 for botro
# City not found. Skipping.....
# Processing Record 154 for chastoozerye
# Processing Record 155 for leningradskiy
# Processing Record 156 for bambanglipuro
# Processing Record 157 for ilabaya
# Processing Record 158 for la palma
# Processing Record 159 for awjilah
# Processing Record 160 for lavrentiya
# Processing Record 161 for buala
# Processing Record 162 for kaitangata
# Processing Record 163 for presidencia roque saenz pena
# Processing Record 164 for penzance
# Processing Record 165 for nome
# Processing Record 166 for bonthe
# Processing Record 167 for vaini
# Processing Record 168 for mocuba
# Processing Record 169 for bethel
# City not found. Skipping.....
# Processing Record 169 for palabuhanratu
# Processing Record 170 for perth
# Processing Record 171 for kurgunta
# Processing Record 172 for quixeramobim
# Processing Record 173 for dongsheng
# Processing Record 174 for manaus
# Processing Record 175 for ancud
# City not found. Skipping.....
# Processing Record 175 for rawannawi
# Processing Record 176 for bengkulu
# Processing Record 177 for klaksvik
# Processing Record 178 for pevek
# Processing Record 179 for port-gentil
# Processing Record 180 for sjoholt
# Processing Record 181 for khatanga
# Processing Record 182 for kilakarai
# Processing Record 183 for tuscaloosa
# City not found. Skipping.....
# Processing Record 183 for artyk
# Processing Record 184 for hami
# Processing Record 185 for savalou
# Processing Record 186 for shiyan
# City not found. Skipping.....
# Processing Record 186 for ondorhaan
# Processing Record 187 for wufeng
# Processing Record 188 for ocos
# Processing Record 189 for cadillac
# Processing Record 190 for constitucion
# Processing Record 191 for lanxi
# Processing Record 192 for bukama
# Processing Record 193 for manggar
# Processing Record 194 for ahuimanu
# Processing Record 195 for george
# Processing Record 196 for hambantota
# Processing Record 197 for vostok
# Processing Record 198 for owase
# Processing Record 199 for tabou
# Processing Record 200 for te anau
# City not found. Skipping.....
# Processing Record 200 for mahadday weyne
# Processing Record 201 for saint anthony
# Processing Record 202 for cherskiy
# Processing Record 203 for longyearbyen
# Processing Record 204 for robertson
# Processing Record 205 for chuy
# Processing Record 206 for ilulissat
# Processing Record 207 for sechura
# Processing Record 208 for mae sai
# Processing Record 209 for kyra
# Processing Record 210 for gazanjyk
# Processing Record 211 for tilichiki
# Processing Record 212 for leh
# Processing Record 213 for tuatapere
# Processing Record 214 for minggang
# City not found. Skipping.....
# Processing Record 214 for malwan
# Processing Record 215 for aykhal
# Processing Record 216 for bathsheba
# Processing Record 217 for samarai
# Processing Record 218 for clyde river
# Processing Record 219 for troy
# Processing Record 220 for praxedis guerrero
# Processing Record 221 for vrangel
# Processing Record 222 for kabwe
# Processing Record 223 for kalaleh
# Processing Record 224 for geraldton
# Processing Record 225 for hervey bay
# Processing Record 226 for viseu
# City not found. Skipping.....
# Processing Record 226 for angra
# Processing Record 227 for dunedin
# Processing Record 228 for upernavik
# City not found. Skipping.....
# Processing Record 228 for illoqqortoormiut
# Processing Record 229 for kamenka
# Processing Record 230 for hadejia
# Processing Record 231 for tura
# Processing Record 232 for tiksi
# Processing Record 233 for moroni
# Processing Record 234 for victoria
# Processing Record 235 for vista hermosa
# Processing Record 236 for raudeberg
# Processing Record 237 for noumea
# Processing Record 238 for laguna
# Processing Record 239 for bowen
# Processing Record 240 for rio gallegos
# Processing Record 241 for miquelon
# Processing Record 242 for briancon
# Processing Record 243 for ketchikan
# Processing Record 244 for tigil
# Processing Record 245 for dubbo
# Processing Record 246 for huarmey
# Processing Record 247 for oil city
# Processing Record 248 for lebu
# Processing Record 249 for cayenne
# Processing Record 250 for ribeira brava
# Processing Record 251 for korla
# Processing Record 252 for mingaora
# Processing Record 253 for jabinyanah
# Processing Record 254 for torbay
# Processing Record 255 for hamilton
# Processing Record 256 for sao gabriel da cachoeira
# Processing Record 257 for fortuna
# Processing Record 258 for nioro
# City not found. Skipping.....
# Processing Record 258 for vaitupu
# Processing Record 259 for tarime
# Processing Record 260 for east london
# Processing Record 261 for mana
# Processing Record 262 for tiznit
# Processing Record 263 for garissa
# Processing Record 264 for bonavista
# Processing Record 265 for chitrakonda
# Processing Record 266 for tiarei
# Processing Record 267 for dumas
# Processing Record 268 for urucui
# Processing Record 269 for malatya
# Processing Record 270 for fort william
# Processing Record 271 for mackenzie
# Processing Record 272 for baykit
# Processing Record 273 for tadine
# Processing Record 274 for olga
# Processing Record 275 for paragominas
# Processing Record 276 for kanigoro
# Processing Record 277 for belaya gora
# Processing Record 278 for lazaro cardenas
# Processing Record 279 for windsor
# Processing Record 280 for santa elena
# Processing Record 281 for cabo san lucas
# Processing Record 282 for vaitape
# Processing Record 283 for denpasar
# Processing Record 284 for takoradi
# Processing Record 285 for port hardy
# Processing Record 286 for kamareddi
# Processing Record 287 for williston
# Processing Record 288 for taree
# Processing Record 289 for san cristobal
# Processing Record 290 for baghdad
# Processing Record 291 for eyl
# Processing Record 292 for praya
# Processing Record 293 for mayo
# Processing Record 294 for honiara
# Processing Record 295 for shimoda
# Processing Record 296 for yulara
# Processing Record 297 for janauba
# Processing Record 298 for mulanje
# Processing Record 299 for southbridge
# Processing Record 300 for porto novo
# Processing Record 301 for berlevag
# Processing Record 302 for orzu
# Processing Record 303 for ondjiva
# Processing Record 304 for winslow
# Processing Record 305 for huilong
# Processing Record 306 for muisne
# Processing Record 307 for mount gambier
# Processing Record 308 for verkhoyansk
# Processing Record 309 for sabha
# Processing Record 310 for tabuk
# City not found. Skipping.....
# Processing Record 310 for tuggurt
# Processing Record 311 for port elizabeth
# Processing Record 312 for derzhavinsk
# Processing Record 313 for itapeva
# Processing Record 314 for koygorodok
# Processing Record 315 for zhangye
# City not found. Skipping.....
# Processing Record 315 for karaul
# Processing Record 316 for fomboni
# Processing Record 317 for vilhena
# Processing Record 318 for los llanos de aridane
# Processing Record 319 for north bend
# Processing Record 320 for nortelandia
# Processing Record 321 for sawtell
# Processing Record 322 for usinsk
# Processing Record 323 for clement town
# Processing Record 324 for yeniseysk
# Processing Record 325 for lagoa
# Processing Record 326 for zatoka
# Processing Record 327 for bodden town
# Processing Record 328 for paracuru
# Processing Record 329 for luau
# Processing Record 330 for mantua
# Processing Record 331 for hofn
# Processing Record 332 for nongan
# Processing Record 333 for vynohradove
# Processing Record 334 for paita
# Processing Record 335 for markova
# Processing Record 336 for ndele
# Processing Record 337 for boyolangu
# City not found. Skipping.....
# Processing Record 337 for sentyabrskiy
# Processing Record 338 for peniche
# Processing Record 339 for teya
# Processing Record 340 for kisangani
# Processing Record 341 for jinzhou
# Processing Record 342 for reforma
# Processing Record 343 for sampit
# Processing Record 344 for sarangani
# Processing Record 345 for ampanihy
# Processing Record 346 for udachnyy
# Processing Record 347 for joshimath
# Processing Record 348 for iqaluit
# Processing Record 349 for timbiqui
# Processing Record 350 for mayumba
# Processing Record 351 for sivaki
# Processing Record 352 for henties bay
# City not found. Skipping.....
# Processing Record 352 for saryshagan
# Processing Record 353 for narsaq
# Processing Record 354 for tessalit
# Processing Record 355 for sobolevo
# Processing Record 356 for marystown
# Processing Record 357 for port blair
# Processing Record 358 for aksu
# Processing Record 359 for aras
# Processing Record 360 for salalah
# Processing Record 361 for esperance
# Processing Record 362 for perevolotskiy
# Processing Record 363 for aksarka
# Processing Record 364 for komsomolskiy
# City not found. Skipping.....
# Processing Record 364 for zhanatas
# Processing Record 365 for khash
# Processing Record 366 for fairbanks
# Processing Record 367 for sao jose da coroa grande
# City not found. Skipping.....
# Processing Record 367 for sofiysk
# City not found. Skipping.....
# Processing Record 367 for tumannyy
# Processing Record 368 for granados
# City not found. Skipping.....
# Processing Record 368 for karakendzha
# Processing Record 369 for saint-augustin
# Processing Record 370 for micheweni
# Processing Record 371 for manyana
# Processing Record 372 for margate
# Processing Record 373 for katete
# Processing Record 374 for ust-kuyga
# Processing Record 375 for shaunavon
# Processing Record 376 for santa cruz
# Processing Record 377 for camopi
# Processing Record 378 for breves
# Processing Record 379 for isla vista
# Processing Record 380 for simao
# Processing Record 381 for pula
# Processing Record 382 for saint-leu
# City not found. Skipping.....
# Processing Record 382 for nizhneyansk
# Processing Record 383 for taoudenni
# Processing Record 384 for nichinan
# Processing Record 385 for puerto leguizamo
# Processing Record 386 for chuguyevka
# Processing Record 387 for dharchula
# Processing Record 388 for hastings
# Processing Record 389 for santa vitoria do palmar
# Processing Record 390 for la macarena
# Processing Record 391 for puerto madryn
# Processing Record 392 for bulawayo
# Processing Record 393 for obo
# City not found. Skipping.....
# Processing Record 393 for lolua
# Processing Record 394 for yellandu
# Processing Record 395 for aberdeen
# Processing Record 396 for kasangulu
# Processing Record 397 for yunyang
# Processing Record 398 for horki
# Processing Record 399 for kalmunai
# Processing Record 400 for maragogi
# Processing Record 401 for chapais
# Processing Record 402 for shakawe
# Processing Record 403 for daru
# Processing Record 404 for yumen
# Processing Record 405 for narnaund
# Processing Record 406 for mizan teferi
# Processing Record 407 for mbarara
# Processing Record 408 for richards bay
# Processing Record 409 for kamaishi
# Processing Record 410 for itacare
# Processing Record 411 for campoverde
# Processing Record 412 for coahuayana
# Processing Record 413 for grindavik
# Processing Record 414 for fethiye
# Processing Record 415 for hualmay
# City not found. Skipping.....
# Processing Record 415 for saleaula
# Processing Record 416 for lompoc
# Processing Record 417 for san patricio
# Processing Record 418 for khuzdar
# Processing Record 419 for lai
# Processing Record 420 for talavera
# Processing Record 421 for qasigiannguit
# Processing Record 422 for vanimo
# Processing Record 423 for evansville
# Processing Record 424 for vestmanna
# Processing Record 425 for boguchany
# Processing Record 426 for calvinia
# Processing Record 427 for pacific grove
# Processing Record 428 for maniitsoq
# Processing Record 429 for berezniki
# Processing Record 430 for pisco
# Processing Record 431 for marrakesh
# Processing Record 432 for plaeng yao
# Processing Record 433 for saint-joseph
# Processing Record 434 for ponta delgada
# Processing Record 435 for mandalgovi
# Processing Record 436 for kieta
# City not found. Skipping.....
# Processing Record 436 for longlac
# Processing Record 437 for traverse city
# Processing Record 438 for alyangula
# Processing Record 439 for general roca
# Processing Record 440 for maumere
# Processing Record 441 for port lincoln
# Processing Record 442 for svetlogorsk
# Processing Record 443 for sioux lookout
# Processing Record 444 for phetchaburi
# Processing Record 445 for kroya
# Processing Record 446 for jerez
# City not found. Skipping.....
# Processing Record 446 for anar darreh
# Processing Record 447 for champerico
# Processing Record 448 for nemuro
# Processing Record 449 for hirara
# Processing Record 450 for nuuk
# Processing Record 451 for banda aceh
# Processing Record 452 for bandarbeyla
# Processing Record 453 for kot diji
# Processing Record 454 for barela
# Processing Record 455 for zorleni
# Processing Record 456 for laguna de perlas
# Processing Record 457 for san isidro
# Processing Record 458 for voskresenskoye
# Processing Record 459 for mentougou
# Processing Record 460 for quirinopolis
# Processing Record 461 for nkwerre
# Processing Record 462 for dalianwan
# Processing Record 463 for solano
# Processing Record 464 for saldanha
# Processing Record 465 for porbandar
# Processing Record 466 for washougal
# Processing Record 467 for yovon
# Processing Record 468 for bamiantong
# Processing Record 469 for kirakira
# Processing Record 470 for touros
# Processing Record 471 for pangody
# Processing Record 472 for ryomgard
# Processing Record 473 for jiexiu
# Processing Record 474 for nagyszenas
# Processing Record 475 for kigoma
# Processing Record 476 for vuktyl
# Processing Record 477 for padang
# Processing Record 478 for bayir
# Processing Record 479 for roma
# Processing Record 480 for deputatskiy
# Processing Record 481 for rhyl
# Processing Record 482 for lasa
# Processing Record 483 for athabasca
# Processing Record 484 for katsuura
# Processing Record 485 for puerto rondon
# Processing Record 486 for luganville
# Processing Record 487 for grootfontein
# Processing Record 488 for gat
# Processing Record 489 for nizwa
# Processing Record 490 for mehamn
# Processing Record 491 for rio grande
# Processing Record 492 for yenangyaung
# Processing Record 493 for chifeng
# Processing Record 494 for eina
# Processing Record 495 for warmbad
# Processing Record 496 for kirkenes
# Processing Record 497 for mackay
# Processing Record 498 for metro
# Processing Record 499 for saint-francois
# Processing Record 500 for lata
# City not found. Skipping.....
# Processing Record 500 for jiddah
# Processing Record 501 for broken hill
# Processing Record 502 for northam
# Processing Record 503 for nishihara
# Processing Record 504 for iracoubo
# Processing Record 505 for ulladulla
# Processing Record 506 for bom jesus
# Processing Record 507 for mbanza-ngungu
# Processing Record 508 for ilhabela
# Processing Record 509 for scicli
# City not found. Skipping.....
# Processing Record 509 for ust-kamchatsk
# Processing Record 510 for saint-pierre
# Processing Record 511 for novikovo
# Processing Record 512 for yei
# Processing Record 513 for nezhinka
# Processing Record 514 for plainview
# Processing Record 515 for evensk
# Processing Record 516 for egvekinot
# City not found. Skipping.....
# Processing Record 516 for kuche
# Processing Record 517 for ziro
# Processing Record 518 for odienne
# Processing Record 519 for mabalacat
# Processing Record 520 for faanui
# Processing Record 521 for nalut
# Processing Record 522 for nizhniy kuranakh
# Processing Record 523 for ochsenfurt
# Processing Record 524 for mopipi
# City not found. Skipping.....
# Processing Record 524 for astipalaia
# Processing Record 525 for phalaborwa
# Processing Record 526 for saint george
# Processing Record 527 for bubaque
# Processing Record 528 for praia da vitoria
# Processing Record 529 for erenhot
# Processing Record 530 for sorland
# Processing Record 531 for gallipoli
# Processing Record 532 for dong hoi
# City not found. Skipping.....
# Processing Record 532 for naugarzan
# Processing Record 533 for severobaykalsk
# Processing Record 534 for samfya
# Processing Record 535 for mankono
# Processing Record 536 for mata
# Processing Record 537 for tulsipur
# Processing Record 538 for alamogordo
# Processing Record 539 for caravelas
# Processing Record 540 for tallahassee
# City not found. Skipping.....
# Processing Record 540 for halalo
# Processing Record 541 for sebinkarahisar
# Processing Record 542 for oranjemund
# City not found. Skipping.....
# Processing Record 542 for yirol
# Processing Record 543 for cam ranh
# Processing Record 544 for clinton
# Processing Record 545 for maryville
# Processing Record 546 for christchurch
# Processing Record 547 for sabana de torres
# Processing Record 548 for chipinge
# Processing Record 549 for avera
# Processing Record 550 for yuty
# Processing Record 551 for yelizovo
# Processing Record 552 for nigran
# Processing Record 553 for kill
# Processing Record 554 for ananas
# Processing Record 555 for remeti
# City not found. Skipping.....
# Processing Record 555 for kollumerland
# Processing Record 556 for indiana
# Processing Record 557 for tumbagaan
# Processing Record 558 for maridi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict={
    "City": name,
    "Latitude": lat,
    "Longitude": long,
    "Max Temperature": maxtemp,
    "Humidity": humid,
    "Cloudiness": cloud,
    "Wind Speed": windsp,
    "Country": country,
    "Date": date,
}
city_data_pd= pd.DataFrame(city_dict)
city_data_pd
# Out:
#           City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0     Arrecife   28.9630   -13.5477            71.67        64           0
# 1       Dikson   73.5069    80.5464            -2.13        90         100
# 2     Lüderitz  -26.6481    15.1594            76.68        58           4
# 3       Rawson  -43.3002   -65.1023            63.86        70          98
# 4       Barrow   71.2906  -156.7887           -29.18        75           0
# ..         ...       ...        ...              ...       ...         ...
# 553     Ananas   19.2466   -71.9557            74.77        64          20
# 554     Remeţi   47.9833    23.6333            35.47        96          98
# 555    Indiana   40.0003   -86.2503            14.74        83         100
# 556  Tumbagaan    5.3656   120.3139            79.47        78         100
# 557     Maridi    4.9158    29.4742            93.78        15         100
#
#      Wind Speed Country        Date
# 0          9.22      ES  1643985399
# 1          5.17      RU  1643985125
# 2         15.84      NA  1643985399
# 3         22.86      AR  1643985399
# 4          5.75      US  1643985400
# ..          ...     ...         ...
# 553       13.22      HT  1643985907
# 554        3.13      RO  1643985907
# 555        8.05      US  1643985750
# 556        7.34      PH  1643985908
# 557        6.67      SS  1643985908
#
# [558 rows x 9 columns]

# %%
#export to csv
city_data_pd.to_csv("output_data/cities.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#because I chose to not seed my cities, this need to be run each time because the data is fluid and changing 
#reduce the dataset by only taking the cities that have a humidity less than 100%
#rather than dropping the ones that dont meet the desired conditions, keep the ones that do   

clean_city_data=city_data_pd[city_data_pd["Humidity"] < 100]
clean_city_data.count()
# Out:
# City               537
# Latitude           537
# Longitude          537
# Max Temperature    537
# Humidity           537
# Cloudiness         537
# Wind Speed         537
# Country            537
# Date               537
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today=pd.Timestamp("today").strftime("%m/%d/%Y")
today
# Out:
# '02/04/2022'

# %%
x_values = clean_city_data['Latitude']
y_values = clean_city_data['Max Temperature']
plot_title='Global - Latitude vs. Max Temperature'

plt.scatter(x_values,y_values)

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f'{plot_title} on {today}')

plt.savefig(f'output_data/plots/{plot_title}.png')

plt.show()

# %%
print('Globally, you can see lower max temperatures the further you go away from the equator. You can also see the impact of seasons as it is winter in the northern hemisphere, resulting in lower temps.')
# Out:
# Globally, you can see lower max temperatures the further you go away from the equator. You can also see the impact of seasons as it is winter in the northern hemisphere, resulting in lower temps.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data['Latitude']
h_values = clean_city_data['Humidity']
plot_title='Global - Latitude vs. Humidity'


plt.scatter(x_values,h_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'{plot_title} on {today}')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data['Latitude']
c_values = clean_city_data['Cloudiness']
plot_title='Global - Latitude vs. Cloudiness'


plt.scatter(x_values,c_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'{plot_title} on {today}')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data['Latitude']
w_values = clean_city_data['Wind Speed']
plot_title='Global - Latitude vs. Wind Speed'


plt.scatter(x_values,w_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'{plot_title} on {today}')

plt.savefig(f'output_data/plots/{plot_title}.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
x_values = clean_city_data['Latitude']
y_values = clean_city_data['Max Temperature']
plot_title='Global - Latitude vs. Max Temperature'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title} regression.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.5637027782675107

# %%
#Filter together northern and southern hemispheres into their own DF's
northern_df=clean_city_data.loc[clean_city_data["Latitude"] >=0,:]
southern_df=clean_city_data.loc[clean_city_data["Latitude"] <0,:]

# %%
northern_df.head()
# Out:
#        City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0  Arrecife   28.9630   -13.5477            71.67        64           0
# 1    Dikson   73.5069    80.5464            -2.13        90         100
# 4    Barrow   71.2906  -156.7887           -29.18        75           0
# 7    Dwārka   22.2394    68.9678            70.54        57           0
# 9    Tanout   14.9709     8.8879            75.90         8           0
#
#    Wind Speed Country        Date
# 0        9.22      ES  1643985399
# 1        5.17      RU  1643985125
# 4        5.75      US  1643985400
# 7       10.54      IN  1643985401
# 9       17.78      NE  1643985402

# %%
southern_df.head()
# Out:
#           City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 2     Lüderitz  -26.6481    15.1594            76.68        58           4
# 3       Rawson  -43.3002   -65.1023            63.86        70          98
# 5       Talara   -4.5772   -81.2719            74.16        73           0
# 6   Bredasdorp  -34.5322    20.0403            73.27        46          43
# 8  New Norfolk  -42.7826   147.0587            59.92        71          79
#
#    Wind Speed Country        Date
# 2       15.84      NA  1643985399
# 3       22.86      AR  1643985399
# 5       24.16      PE  1643985400
# 6       14.97      ZA  1643985401
# 8        1.48      AU  1643985402

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Max Temperature']
plot_title = 'Northern Hemisphere - Max Temp vs. Latitude'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.7056899464933067

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Max Temperature']
plot_title='Southern Hemisphere - Max Temp vs. Latitude'

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.38334479660988835

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
h_values = northern_df['Humidity']
plot_title='Northern Hemisphere - Humidity (%) vs. Latitude'

# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, h_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,h_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.1669154262355869

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
h_values = southern_df['Humidity']
plot_title='Southern Hemisphere - Humidity (%) vs. Latitude '


# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, h_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,h_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.015621529410962905

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
c_values = northern_df['Cloudiness']
plot_title='Northern Hemisphere - Cloudiness (%) vs. Latitude'

# Perform a linear regression on cloudiness vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, c_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,c_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.08931259514118474

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
c_values = southern_df['Cloudiness']
plot_title='Southern Hemisphere - Cloudiness (%) vs. Latitude'

# Perform a linear regression on latitude vs cloudiness
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, c_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,c_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.0345033461746264

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
w_values = northern_df['Wind Speed']
plot_title='Northern Hemisphere - Wind Speed (mph) vs. Latitude'


# Perform a linear regression on latitude vs wind speed
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, w_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,w_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.03231405220194027

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
w_values = southern_df['Wind Speed']
plot_title='Southern Hemisphere - Wind Speed (mph) vs. Latitude'

# Perform a linear regression on latitude vs. windspeed
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, w_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,w_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f'{plot_title} on {today}')


# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig(f'output_data/plots/{plot_title}.png')

# Show plot
plt.show()
# Out:
# The r-value is: 0.020028631425872783
